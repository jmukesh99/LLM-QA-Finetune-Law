# %%
# Number of lines to read
n = 5
file_path = "/kaggle/input/aibe-mcq-silver-training-dataset/aibe-315-silver-text-format.jsonl"
with open(file_path, 'r') as file:
    total_line = file.readlines()
    length = []
    for _ in total_line:
        length.append(len(_))
    avg = sum(length)/len(length)
    print(min(length), max(length), avg)
    
        
    
#     for _ in range(n):
#         line = file.readline().strip()
#         data = json.loads(line)
#         print(data)
# Out:
# 246 1660 520.815873015873

# %%
# !pip -q install git+https://github.com/huggingface/transformers # need to install from github

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import torch
import transformers
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
                                          use_auth_token=True,
                                          )
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:648: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Loading the tokenizer from the `special_tokens_map.json` and the `added_tokens.json` will be removed in `transformers 5`,  it is kept for forward compatibility, but it is recommended to update your `tokenizer_config.json` by uploading it again. You will see the new `added_tokens_decoder` attribute that will store the relevant information.

# %%
file_path = "/kaggle/input/aibe-mcq-silver-training-dataset/aibe-315-silver-text-format.jsonl"
with open(file_path, 'r') as file:
    total_line = file.readlines()
    length = []
    for _ in total_line[0:1]:
        length.append(tokenizer.tokenize(_))
    print(length)
    print(_)
# Out:
# [['▁{"', 'text', '":', '▁"', '##', '#', '▁Question', '▁The', '▁object', 'ives', '▁of', '▁the', '▁EU', '▁Direct', 'ive', '▁on', '▁med', 'iation', '▁is', ':', '▁###', '▁Options', "▁['", 'a', ')', '▁Red', 'uc', 'ing', '▁back', 'logs', '▁of', '▁cases', '▁at', '▁the', '▁courts', '▁in', '▁the', '▁member', '▁states', "',", "▁'", 'b', ')', '▁D', 'ivid', 'ing', '▁the', '▁cases', '▁between', '▁all', '▁the', '▁dispute', '▁resolution', '▁methods', "',", "▁'", 'c', ')', '▁Econom', 'ical', '▁reasons', '▁in', '▁times', '▁of', '▁crisis', ',', '▁thus', '▁ens', 'uring', '▁that', '▁medi', 'ators', '▁will', '▁have', '▁a', '▁better', '▁a', '▁proper', '▁income', '.', "',", "▁'", 'd', ')', '▁Ens', 'uring', '▁better', '▁access', '▁to', '▁alternative', '▁dispute', '▁resolution', '▁in', '▁cross', '-', 'border', '▁commercial', '▁conflicts', '.', "']", '▁###', '▁Answer', '▁d', ')', '▁Ens', 'uring', '▁better', '▁access', '▁to', '▁alternative', '▁dispute', '▁resolution', '▁in', '▁cross', '-', 'border', '▁commercial', '▁conflicts', '.', '▁###', '▁Ex', 'plan', 'ation', '▁The', '▁main', '▁aim', '▁of', '▁the', '▁EU', '▁Direct', 'ive', '▁on', '▁med', 'iation', '▁is', '▁to', '▁facil', 'itate', '▁access', '▁to', '▁alternative', '▁dispute', '▁resolution', '▁and', '▁to', '▁promote', '▁the', '▁am', 'ic', 'able', '▁settlement', '▁of', '▁disput', 'es', '▁by', '▁encourag', 'ing', '▁the', '▁use', '▁of', '▁med', 'iation', '."', '}', '<0x0A>']]
# {"text": "### Question The objectives of the EU Directive on mediation is: ### Options ['a) Reducing backlogs of cases at the courts in the member states', 'b) Dividing the cases between all the dispute resolution methods', 'c) Economical reasons in times of crisis, thus ensuring that mediators will have a better a proper income.', 'd) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts.'] ### Answer d) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts. ### Explanation The main aim of the EU Directive on mediation is to facilitate access to alternative dispute resolution and to promote the amicable settlement of disputes by encouraging the use of mediation."}

# %%
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf",
                                          use_auth_token=True,
                                          )
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
file_path = "/kaggle/input/aibe-mcq-silver-training-dataset/aibe-315-silver-text-format.jsonl"
with open(file_path, 'r') as file:
    total_line = file.readlines()
    length = []
    for _ in total_line[0:1]:
        length.append(tokenizer.tokenize(_.index("text")))
    print(length)
    print(_)
# Out:
# [['▁{"', 'text', '":', '▁"', '##', '#', '▁Question', '▁The', '▁object', 'ives', '▁of', '▁the', '▁EU', '▁Direct', 'ive', '▁on', '▁med', 'iation', '▁is', ':', '▁###', '▁Options', "▁['", 'a', ')', '▁Red', 'uc', 'ing', '▁back', 'logs', '▁of', '▁cases', '▁at', '▁the', '▁courts', '▁in', '▁the', '▁member', '▁states', "',", "▁'", 'b', ')', '▁D', 'ivid', 'ing', '▁the', '▁cases', '▁between', '▁all', '▁the', '▁dispute', '▁resolution', '▁methods', "',", "▁'", 'c', ')', '▁Econom', 'ical', '▁reasons', '▁in', '▁times', '▁of', '▁crisis', ',', '▁thus', '▁ens', 'uring', '▁that', '▁medi', 'ators', '▁will', '▁have', '▁a', '▁better', '▁a', '▁proper', '▁income', '.', "',", "▁'", 'd', ')', '▁Ens', 'uring', '▁better', '▁access', '▁to', '▁alternative', '▁dispute', '▁resolution', '▁in', '▁cross', '-', 'border', '▁commercial', '▁conflicts', '.', "']", '▁###', '▁Answer', '▁d', ')', '▁Ens', 'uring', '▁better', '▁access', '▁to', '▁alternative', '▁dispute', '▁resolution', '▁in', '▁cross', '-', 'border', '▁commercial', '▁conflicts', '.', '▁###', '▁Ex', 'plan', 'ation', '▁The', '▁main', '▁aim', '▁of', '▁the', '▁EU', '▁Direct', 'ive', '▁on', '▁med', 'iation', '▁is', '▁to', '▁facil', 'itate', '▁access', '▁to', '▁alternative', '▁dispute', '▁resolution', '▁and', '▁to', '▁promote', '▁the', '▁am', 'ic', 'able', '▁settlement', '▁of', '▁disput', 'es', '▁by', '▁encourag', 'ing', '▁the', '▁use', '▁of', '▁med', 'iation', '."', '}', '<0x0A>']]
# {"text": "### Question The objectives of the EU Directive on mediation is: ### Options ['a) Reducing backlogs of cases at the courts in the member states', 'b) Dividing the cases between all the dispute resolution methods', 'c) Economical reasons in times of crisis, thus ensuring that mediators will have a better a proper income.', 'd) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts.'] ### Answer d) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts. ### Explanation The main aim of the EU Directive on mediation is to facilitate access to alternative dispute resolution and to promote the amicable settlement of disputes by encouraging the use of mediation."}

# %%
file_path = "/kaggle/input/aibe-mcq-silver-training-dataset/aibe-315-silver-text-format.jsonl"
with open(file_path, 'r') as file:
    total_line = file.readlines()
    length = []
    for _ in total_line[0:1]:
        length.append(_[_.index("text"):])
    print(length)
    print(_)
# Out:
# ['text": "### Question The objectives of the EU Directive on mediation is: ### Options [\'a) Reducing backlogs of cases at the courts in the member states\', \'b) Dividing the cases between all the dispute resolution methods\', \'c) Economical reasons in times of crisis, thus ensuring that mediators will have a better a proper income.\', \'d) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts.\'] ### Answer d) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts. ### Explanation The main aim of the EU Directive on mediation is to facilitate access to alternative dispute resolution and to promote the amicable settlement of disputes by encouraging the use of mediation."}\n']
# {"text": "### Question The objectives of the EU Directive on mediation is: ### Options ['a) Reducing backlogs of cases at the courts in the member states', 'b) Dividing the cases between all the dispute resolution methods', 'c) Economical reasons in times of crisis, thus ensuring that mediators will have a better a proper income.', 'd) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts.'] ### Answer d) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts. ### Explanation The main aim of the EU Directive on mediation is to facilitate access to alternative dispute resolution and to promote the amicable settlement of disputes by encouraging the use of mediation."}

# %%
import pandas as pd
df = pd.read_csv("/kaggle/input/aibe-mcq-silver-training-dataset/All_India_Bar_Exam-MCQs_Experiment - (315)All-Silver.csv")
print(list(df.head(2)))
# Out:
# ['Question', 'Options', 'Answer', 'Explanation']

# %%
tokenizer.tokenize("""<s> [INST]
<<SYS>>""")
# Out:
# ['<s>', '▁', '▁[', 'INST', ']', '<0x0A>', '<<', 'SY', 'S', '>>']

# %%
tokenizer.tokenize("<s> [INST] <<SYS>> </s>")
# Out:
# ['<s>', '▁', '▁[', 'INST', ']', '▁<<', 'SY', 'S', '>>', '▁', '</s>']

# %%
import pandas as pd
import json

# Load the CSV file
df_prompt = pd.read_csv("/kaggle/input/aibe-mcq-silver-training-dataset/All_India_Bar_Exam-MCQs_Experiment - (315)All-Silver.csv")

# Define the prompt template
prompt_template = """<s> [INST]
<<SYS>>
You are an AI model assigned the role of a legal expert, specifically trained on a vast majority of Indian law text data. Your primary task is to answer multiple choice questions from the All India Bar Examination. It's imperative that you provide authentic and factual answers. Remember, wrong answers will lead to a deduction in marks. 

Always ensure that only one option is correct. Think critically about all the options provided. Recall the extensive Indian law data you've been trained on to make an informed decision. After choosing the right answer, provide a brief explanation justifying your choice, highlighting relevant facts and ideas pertaining to the question.
<</SYS>>
### Question: {{ question_text }} 
### Options: {{ options_list }} [/INST] 
{{ model_answer }} </s>
"""

# Create a list of formatted texts
formatted_texts = []
for _, row in df_prompt.iterrows():
    formatted_text = prompt_template.replace("{{ question_text }}", row["Question"])
    formatted_text = formatted_text.replace("{{ options_list }}", row["Options"])
    model_answer = row["Answer"]
    if pd.notnull(row["Explanation"]):
        model_answer += " " + row["Explanation"]
    formatted_text = formatted_text.replace("{{ model_answer }}", model_answer)
    formatted_texts.append(formatted_text)

# Convert the list of formatted texts to JSONL format
jsonl_data = [{"text": text} for text in formatted_texts]
jsonl_output_path_prompt = "/kaggle/working/train.jsonl"
with open(jsonl_output_path_prompt, 'w') as jsonl_file:
    for item in jsonl_data:
        jsonl_file.write(json.dumps(item) + '\n')

# %%
file_path = "/kaggle/working/train.jsonl"
with open(file_path, 'r') as file:
    total_line = file.readlines()
    length = []
    for _ in total_line:
        length.append(len(_))
    avg = sum(length)/len(length)
    print(min(length), max(length), avg)
    
    for _ in total_line[0:1]:
        print(_)
# Out:
# 951 2365 1225.815873015873
# {"text": "<s> [INST]\n<<SYS>>\nYou are an AI model assigned the role of a legal expert, specifically trained on a vast majority of Indian law text data. Your primary task is to answer multiple choice questions from the All India Bar Examination. It's imperative that you provide authentic and factual answers. Remember, wrong answers will lead to a deduction in marks. \n\nAlways ensure that only one option is correct. Think critically about all the options provided. Recall the extensive Indian law data you've been trained on to make an informed decision. After choosing the right answer, provide a brief explanation justifying your choice, highlighting relevant facts and ideas pertaining to the question.\n<</SYS>>\n### Question: The objectives of the EU Directive on mediation is: \n### Options: ['a) Reducing backlogs of cases at the courts in the member states', 'b) Dividing the cases between all the dispute resolution methods', 'c) Economical reasons in times of crisis, thus ensuring that mediators will have a better a proper income.', 'd) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts.'] [/INST] \nd) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts. The main aim of the EU Directive on mediation is to facilitate access to alternative dispute resolution and to promote the amicable settlement of disputes by encouraging the use of mediation. </s>\n"}

# %%
import pandas as pd
test_df = pd.read_csv("/kaggle/input/aibe-mcq-testing-dataset/AIBE-XVII.csv")
test_df.head(5)
# Out:
#                                             Question  \
# 0  1. The Section 12 of Hindu Maintenance and Ado...
# 1  2. Which of the following categories of cases ...
# 2  3. Who is known as Father of Public Interest L...
# 3  4. Which of the following is not a real purpos...
# 4  5. In Hussainara Khatoon Vs. State of Bihar, _...
#
#                                               Option
# 0  ['(A) Rights of adoptive parents to dispose of...
# 1  ['(A) Family Pension', '(B) Petitions from rio...
# 2  ['(A) Justice A. N. Ray', '(B) Justice Y. V. C...
# 3  ['(A) Vindication of the rule of law', '(B) Fa...
# 4  ['(A) Right to Speedy Justice', '(B) Right to ...

# %%
# Load the CSV file
df_prompt = pd.read_csv("/kaggle/input/aibe-mcq-testing-dataset/AIBE-XVII.csv")

# Define the prompt template
prompt_template = """<s> [INST]
<<SYS>>
You are an AI model assigned the role of a legal expert, specifically trained on a vast majority of Indian law text data. Your primary task is to answer multiple choice questions from the All India Bar Examination. It's imperative that you provide authentic and factual answers. Remember, wrong answers will lead to a deduction in marks. 

Always ensure that only one option is correct. Think critically about all the options provided. Recall the extensive Indian law data you've been trained on to make an informed decision. After choosing the right answer, provide a brief explanation justifying your choice, highlighting relevant facts and ideas pertaining to the question.
<</SYS>>
### Question: {{ question_text }} 
### Options: {{ options_list }} [/INST]
"""

# Create a list of formatted texts
formatted_texts = []
for _, row in df_prompt.iterrows():
    formatted_text = prompt_template.replace("{{ question_text }}", row["Question"])
    formatted_text = formatted_text.replace("{{ options_list }}", row["Option"])
#     model_answer = row["Answer"]
#     if pd.notnull(row["Explanation"]):
#         model_answer += " " + row["Explanation"]
#     formatted_text = formatted_text.replace("{{ model_answer }}", model_answer)
    formatted_texts.append(formatted_text)

# Convert the list of formatted texts to JSONL format
jsonl_data = [{"text": text} for text in formatted_texts]
jsonl_output_path_prompt = "/kaggle/working/test.jsonl"
with open(jsonl_output_path_prompt, 'w') as jsonl_file:
    for item in jsonl_data:
        jsonl_file.write(json.dumps(item) + '\n')

# %%
file_path = "/kaggle/working/test.jsonl"
with open(file_path, 'r') as file:
    total_line = file.readlines()
    length = []
    for _ in total_line:
        length.append(len(_))
    avg = sum(length)/len(length)
    print(min(length), max(length), avg)
    
    for _ in total_line[0:1]:
        print(_)
# Out:
# 879 1567 1032.53
# {"text": "<s> [INST]\n<<SYS>>\nYou are an AI model assigned the role of a legal expert, specifically trained on a vast majority of Indian law text data. Your primary task is to answer multiple choice questions from the All India Bar Examination. It's imperative that you provide authentic and factual answers. Remember, wrong answers will lead to a deduction in marks. \n\nAlways ensure that only one option is correct. Think critically about all the options provided. Recall the extensive Indian law data you've been trained on to make an informed decision. After choosing the right answer, provide a brief explanation justifying your choice, highlighting relevant facts and ideas pertaining to the question.\n<</SYS>>\n### Question: 1. The Section 12 of Hindu Maintenance and Adoption Act, 1956 deals with \n### Options: ['(A) Rights of adoptive parents to dispose of their properties', '(B) Effects of adoption', '(C) Presumption as to the document relating to adoption', '(D) Cancellation of adoption'] [/INST]\n"}

# %%
tokenizer.tokenize("\n<s>[INST] <<SYS>>\nYou are an AI model assigned the role of a legal expert, specifically trained on a vast majority of Indian law text data. Your primary task is to answer multiple choice questions from the All India Bar Examination. It's imperative that you provide authentic and factual answers. Remember, wrong answers will lead to a deduction in marks. \n\nAlways ensure that only one option is correct. Think critically about all the options provided. Recall the extensive Indian law data you've been trained on to make an informed decision. After choosing the right answer, provide a brief explanation justifying your choice, highlighting relevant facts and ideas pertaining to the question.\n<</SYS>>\n\n\n### Question: The objectives of the EU Directive on mediation is: \n### Options: ['a) Reducing backlogs of cases at the courts in the member states', 'b) Dividing the cases between all the dispute resolution methods', 'c) Economical reasons in times of crisis, thus ensuring that mediators will have a better a proper income.', 'd) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts.'] \n[/INST] d) Ensuring better access to alternative dispute resolution in cross-border commercial conflicts. The main aim of the EU Directive on mediation is to facilitate access to alternative dispute resolution and to promote the amicable settlement of disputes by encouraging the use of mediation.\n")
# Out:
# ['▁',
#  '<0x0A>',
#  '<s>',
#  '▁[',
#  'INST',
#  ']',
#  '▁<<',
#  'SY',
#  'S',
#  '>>',
#  '<0x0A>',
#  'You',
#  '▁are',
#  '▁an',
#  '▁A',
#  'I',
#  '▁model',
#  '▁assigned',
#  '▁the',
#  '▁role',
#  '▁of',
#  '▁a',
#  '▁legal',
#  '▁expert',
#  ',',
#  '▁specifically',
#  '▁trained',
#  '▁on',
#  '▁a',
#  '▁vast',
#  '▁majority',
#  '▁of',
#  '▁Indian',
#  '▁law',
#  '▁text',
#  '▁data',
#  '.',
#  '▁Your',
#  '▁primary',
#  '▁task',
#  '▁is',
#  '▁to',
#  '▁answer',
#  '▁multiple',
#  '▁choice',
#  '▁questions',
#  '▁from',
#  '▁the',
#  '▁All',
#  '▁India',
#  '▁Bar',
#  '▁Ex',
#  'am',
#  'ination',
#  '.',
#  '▁It',
#  "'",
#  's',
#  '▁imper',
#  'ative',
#  '▁that',
#  '▁you',
#  '▁provide',
#  '▁authentic',
#  '▁and',
#  '▁fact',
#  'ual',
#  '▁answers',
#  '.',
#  '▁Remember',
#  ',',
#  '▁wrong',
#  '▁answers',
#  '▁will',
#  '▁lead',
#  '▁to',
#  '▁a',
#  '▁dedu',
#  'ction',
#  '▁in',
#  '▁marks',
#  '.',
#  '▁',
#  '<0x0A>',
#  '<0x0A>',
#  'Al',
#  'ways',
#  '▁ensure',
#  '▁that',
#  '▁only',
#  '▁one',
#  '▁option',
#  '▁is',
#  '▁correct',
#  '.',
#  '▁Think',
#  '▁crit',
#  'ically',
#  '▁about',
#  '▁all',
#  '▁the',
#  '▁options',
#  '▁provided',
#  '.',
#  '▁Rec',
#  'all',
#  '▁the',
#  '▁extensive',
#  '▁Indian',
#  '▁law',
#  '▁data',
#  '▁you',
#  "'",
#  've',
#  '▁been',
#  '▁trained',
#  '▁on',
#  '▁to',
#  '▁make',
#  '▁an',
#  '▁informed',
#  '▁decision',
#  '.',
#  '▁After',
#  '▁choosing',
#  '▁the',
#  '▁right',
#  '▁answer',
#  ',',
#  '▁provide',
#  '▁a',
#  '▁brief',
#  '▁explanation',
#  '▁just',
#  'ifying',
#  '▁your',
#  '▁choice',
#  ',',
#  '▁highlight',
#  'ing',
#  '▁relevant',
#  '▁facts',
#  '▁and',
#  '▁ideas',
#  '▁per',
#  'tain',
#  'ing',
#  '▁to',
#  '▁the',
#  '▁question',
#  '.',
#  '<0x0A>',
#  '<',
#  '</',
#  'SY',
#  'S',
#  '>>',
#  '<0x0A>',
#  '<0x0A>',
#  '<0x0A>',
#  '##',
#  '#',
#  '▁Question',
#  ':',
#  '▁The',
#  '▁object',
#  'ives',
#  '▁of',
#  '▁the',
#  '▁EU',
#  '▁Direct',
#  'ive',
#  '▁on',
#  '▁med',
#  'iation',
#  '▁is',
#  ':',
#  '▁',
#  '<0x0A>',
#  '##',
#  '#',
#  '▁Options',
#  ':',
#  "▁['",
#  'a',
#  ')',
#  '▁Red',
#  'uc',
#  'ing',
#  '▁back',
#  'logs',
#  '▁of',
#  '▁cases',
#  '▁at',
#  '▁the',
#  '▁courts',
#  '▁in',
#  '▁the',
#  '▁member',
#  '▁states',
#  "',",
#  "▁'",
#  'b',
#  ')',
#  '▁D',
#  'ivid',
#  'ing',
#  '▁the',
#  '▁cases',
#  '▁between',
#  '▁all',
#  '▁the',
#  '▁dispute',
#  '▁resolution',
#  '▁methods',
#  "',",
#  "▁'",
#  'c',
#  ')',
#  '▁Econom',
#  'ical',
#  '▁reasons',
#  '▁in',
#  '▁times',
#  '▁of',
#  '▁crisis',
#  ',',
#  '▁thus',
#  '▁ens',
#  'uring',
#  '▁that',
#  '▁medi',
#  'ators',
#  '▁will',
#  '▁have',
#  '▁a',
#  '▁better',
#  '▁a',
#  '▁proper',
#  '▁income',
#  '.',
#  "',",
#  "▁'",
#  'd',
#  ')',
#  '▁Ens',
#  'uring',
#  '▁better',
#  '▁access',
#  '▁to',
#  '▁alternative',
#  '▁dispute',
#  '▁resolution',
#  '▁in',
#  '▁cross',
#  '-',
#  'border',
#  '▁commercial',
#  '▁conflicts',
#  '.',
#  "']",
#  '▁',
#  '<0x0A>',
#  '[',
#  '/',
#  'INST',
#  ']',
#  '▁d',
#  ')',
#  '▁Ens',
#  'uring',
#  '▁better',
#  '▁access',
#  '▁to',
#  '▁alternative',
#  '▁dispute',
#  '▁resolution',
#  '▁in',
#  '▁cross',
#  '-',
#  'border',
#  '▁commercial',
#  '▁conflicts',
#  '.',
#  '▁The',
#  '▁main',
#  '▁aim',
#  '▁of',
#  '▁the',
#  '▁EU',
#  '▁Direct',
#  'ive',
#  '▁on',
#  '▁med',
#  'iation',
#  '▁is',
#  '▁to',
#  '▁facil',
#  'itate',
#  '▁access',
#  '▁to',
#  '▁alternative',
#  '▁dispute',
#  '▁resolution',
#  '▁and',
#  '▁to',
#  '▁promote',
#  '▁the',
#  '▁am',
#  'ic',
#  'able',
#  '▁settlement',
#  '▁of',
#  '▁disput',
#  'es',
#  '▁by',
#  '▁encourag',
#  'ing',
#  '▁the',
#  '▁use',
#  '▁of',
#  '▁med',
#  'iation',
#  '.',
#  '<0x0A>']

# %%
file_path = "/kaggle/working/prompt_questions.jsonl"

with open(file_path, 'r') as file:
    
    total_line = file.readlines()
    print(len(total_line))
    
    length_token = []
    
    for _ in total_line[0:1]:
        token = list(tokenizer.tokenize(_))
        print(token)
        length_token.append(len(token))
        
    avg = sum(length_token)/len(length_token)
    print(min(length_token), max(length_token), avg)
# Out:
# 315
# ['▁{"', 'text', '":', '▁"\\', 'n', '<s>', '▁[', 'INST', ']', '▁<<', 'SY', 'S', '>>', '\\', 'n', 'You', '▁are', '▁an', '▁A', 'I', '▁model', '▁assigned', '▁the', '▁role', '▁of', '▁a', '▁legal', '▁expert', ',', '▁specifically', '▁trained', '▁on', '▁a', '▁vast', '▁majority', '▁of', '▁Indian', '▁law', '▁text', '▁data', '.', '▁Your', '▁primary', '▁task', '▁is', '▁to', '▁answer', '▁multiple', '▁choice', '▁questions', '▁from', '▁the', '▁All', '▁India', '▁Bar', '▁Ex', 'am', 'ination', '.', '▁It', "'", 's', '▁imper', 'ative', '▁that', '▁you', '▁provide', '▁authentic', '▁and', '▁fact', 'ual', '▁answers', '.', '▁Remember', ',', '▁wrong', '▁answers', '▁will', '▁lead', '▁to', '▁a', '▁dedu', 'ction', '▁in', '▁marks', '.', '▁\\', 'n', '\\', 'n', 'Al', 'ways', '▁ensure', '▁that', '▁only', '▁one', '▁option', '▁is', '▁correct', '.', '▁Think', '▁crit', 'ically', '▁about', '▁all', '▁the', '▁options', '▁provided', '.', '▁Rec', 'all', '▁the', '▁extensive', '▁Indian', '▁law', '▁data', '▁you', "'", 've', '▁been', '▁trained', '▁on', '▁to', '▁make', '▁an', '▁informed', '▁decision', '.', '▁After', '▁choosing', '▁the', '▁right', '▁answer', ',', '▁provide', '▁a', '▁brief', '▁explanation', '▁just', 'ifying', '▁your', '▁choice', ',', '▁highlight', 'ing', '▁relevant', '▁facts', '▁and', '▁ideas', '▁per', 'tain', 'ing', '▁to', '▁the', '▁question', '.\\', 'n', '<', '</', 'SY', 'S', '>>', '\\', 'n', '\\', 'n', '\\', 'n', '##', '#', '▁Question', ':', '▁The', '▁object', 'ives', '▁of', '▁the', '▁EU', '▁Direct', 'ive', '▁on', '▁med', 'iation', '▁is', ':', '▁\\', 'n', '##', '#', '▁Options', ':', "▁['", 'a', ')', '▁Red', 'uc', 'ing', '▁back', 'logs', '▁of', '▁cases', '▁at', '▁the', '▁courts', '▁in', '▁the', '▁member', '▁states', "',", "▁'", 'b', ')', '▁D', 'ivid', 'ing', '▁the', '▁cases', '▁between', '▁all', '▁the', '▁dispute', '▁resolution', '▁methods', "',", "▁'", 'c', ')', '▁Econom', 'ical', '▁reasons', '▁in', '▁times', '▁of', '▁crisis', ',', '▁thus', '▁ens', 'uring', '▁that', '▁medi', 'ators', '▁will', '▁have', '▁a', '▁better', '▁a', '▁proper', '▁income', '.', "',", "▁'", 'd', ')', '▁Ens', 'uring', '▁better', '▁access', '▁to', '▁alternative', '▁dispute', '▁resolution', '▁in', '▁cross', '-', 'border', '▁commercial', '▁conflicts', '.', "']", '▁\\', 'n', '[', '/', 'INST', ']', '▁d', ')', '▁Ens', 'uring', '▁better', '▁access', '▁to', '▁alternative', '▁dispute', '▁resolution', '▁in', '▁cross', '-', 'border', '▁commercial', '▁conflicts', '.', '▁The', '▁main', '▁aim', '▁of', '▁the', '▁EU', '▁Direct', 'ive', '▁on', '▁med', 'iation', '▁is', '▁to', '▁facil', 'itate', '▁access', '▁to', '▁alternative', '▁dispute', '▁resolution', '▁and', '▁to', '▁promote', '▁the', '▁am', 'ic', 'able', '▁settlement', '▁of', '▁disput', 'es', '▁by', '▁encourag', 'ing', '▁the', '▁use', '▁of', '▁med', 'iation', '.\\', 'n', '"}', '<0x0A>']
# 335 335 335.0

# %%
from datasets import load_dataset

# Path to your JSONL file
jsonl_output_path_prompt = "/kaggle/working/prompt_questions.jsonl"

# Load the dataset
dataset = load_dataset('json', data_files=jsonl_output_path_prompt, split='train')

# Display the first few examples from the dataset
print(dataset[:5])
